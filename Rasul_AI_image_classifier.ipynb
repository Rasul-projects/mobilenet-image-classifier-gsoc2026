# %%
# !pip install tensorflow pillow
# Load pretrained MobileNet model trained on ImageNet dataset

# %%
#importung the tensorflow..
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
#model successfull or not completed
model = tf.keras.applications.MobileNetV2(weights="imagenet")
print("Model Loaded Successfully completed")
# Out:
# Model Loaded Successfully completed

# %%
#upload a different images to understanding the how its work..
from google.colab import files

uploaded = files.upload()

img_path = list(uploaded.keys())[0]
print("Image uploaded:", img_path)
# Out:
#      <input type="file" id="files-8758b643-01e1-4ae6-947d-25e579e04e08" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8758b643-01e1-4ae6-947d-25e579e04e08">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
img = Image.open(img_path).resize((224,224))
img_array = np.array(img)/255.0
img_array = np.expand_dims(img_array, axis=0)

prediction = model.predict(img_array)

decoded = tf.keras.applications.mobilenet_v2.decode_predictions(prediction, top=3)

print("Top Predictions:")
for _, label, score in decoded[0]:
    print(label, ":", round(score*100,2), "%")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Top Predictions:
# king_penguin : 99.05 %
# American_egret : 0.04 %
# killer_whale : 0.04 %

# %%
plt.imshow(img)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(223.5), np.float64(223.5), np.float64(-0.5))

# %%
print("Top 5 Predictions:")
decoded = tf.keras.applications.mobilenet_v2.decode_predictions(prediction, top=5)

for i, (_, label, score) in enumerate(decoded[0]):
    print(f"{i+1}. {label} → {round(score*100,2)}%")
# Out:
# Top 5 Predictions:
# 1. king_penguin → 99.05000305175781%
# 2. American_egret → 0.03999999910593033%
# 3. killer_whale → 0.03999999910593033%
# 4. water_jug → 0.03999999910593033%
# 5. crane → 0.019999999552965164%

# %%
print("This project using the MobileNetV2 pretrained model.")
print("It analyzes with uploaded images and predicts the objects using deep learning.")
# Out:
# This project using the MobileNetV2 pretrained model.
# It analyzes with uploaded images and predicts the objects using deep learning.

# %%
#showing image details..
# Show image
plt.imshow(img)
plt.axis("off")
plt.show()

# Decode predictions
decoded = tf.keras.applications.mobilenet_v2.decode_predictions(prediction, top=3)

print("\n=====Rasul- AI Prediction Result =====")
for i, (_, label, score) in enumerate(decoded[0]):
    print(f"{i+1}. Object: {label}")
    print(f"   Confidence: {round(score*100,2)}%")
# Out:
# =====Rasul- AI Prediction Result =====
# 1. Object: king_penguin
#    Confidence: 99.05000305175781%
# 2. Object: American_egret
#    Confidence: 0.03999999910593033%
# 3. Object: killer_whale
#    Confidence: 0.03999999910593033%
